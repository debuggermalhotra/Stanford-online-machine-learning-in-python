# %% [markdown]
# # Linear regression

# %%
#importing modules
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ## Linear regression with one variable

# %%
datafile='data/ex1data1.txt'
#read in comma seperated data
cols=np.loadtxt(datafile,delimiter=',',usecols=(0,1),unpack=True)
x=np.transpose(np.array(cols[:-1]))
y=np.transpose(np.array(cols[-1:]))
#number of training examples
m=y.size
#Insert the usual column of 1s into the "X" matrix
x=np.insert(x,0,1,axis=1)

# %% [markdown]
# #### Plotting the data

# %%
plt.figure(figsize=(10,6))
plt.plot(x[:,1],y[:,0],'rx',markersize=10)
plt.grid(True)
plt.ylabel('Profit in $10,000')
plt.xlabel('Population of City in 10,000')

# %% [markdown]
# ### Gradient Descent

# %%
iterations=1500
aplha=0.01

# %%
#linear hypothesis function
def h(theta,x):
    return np.dot(x,theta) #dot product of x and theta

#cost function also known as J
def computeCost(mytheta,x,y):
    """
    theta_start is an n-dimensional vector of initial theta guess
    X is a matrix of m-rows and n-columns[m x n]
    y is a matrix with m-rows and 1 column
    """
    return float((1./(2*m))*np.dot(h(mytheta,x)-y).T,(h(mytheta,x)-y))
    
initial_theta = np.zeros((x.shape[1],1)) #(theta is a vector with n rows and 1 columns (if X has n features) )
print(computeCost(initial_theta,x,y))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-15-4a7490caadbd> in <module>()
#      13
#      14 initial_theta = np.zeros((x.shape[1],1)) #(theta is a vector with n rows and 1 columns (if X has n features) )
# ---> 15 print(computeCost(initial_theta,x,y))
#
# <ipython-input-15-4a7490caadbd> in computeCost(mytheta, x, y)
#      10     y is a matrix with m-rows and 1 column
#      11     """
# ---> 12     return float((1./(2*m))*np.dot(h(mytheta,x)-y).T,(h(mytheta,x)-y))
#      13
#      14 initial_theta = np.zeros((x.shape[1],1)) #(theta is a vector with n rows and 1 columns (if X has n features) )
#
# TypeError: Required argument 'b' (pos 2) not found
